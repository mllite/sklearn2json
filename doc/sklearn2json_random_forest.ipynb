# %%
import json 

from sklearn.datasets import load_iris

from sklearn.ensemble import RandomForestClassifier

 
clf = RandomForestClassifier()
iris = load_iris()

# %%
clf.fit(iris.data, iris.target)
# Out:
# RandomForestClassifier()

# %%
import sklearn2json

# %%
import numpy as np



class NumpyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        return super(NumpyEncoder, self).default(obj)

# %%
lDict = sklearn2json.convert_model(clf)

lJSON = json.dumps(lDict, cls=NumpyEncoder, sort_keys= True, indent = 4)
# Out:
# CONVERT_MODEL  <class 'sklearn.ensemble._forest.RandomForestClassifier'>

# %%
print(lJSON)
# Out:
# {
#     "classes": [
#         0,
#         1,
#         2
#     ],
#     "forest": {
#         "RF_Tree_000": {
#             "classes": [
#                 0.0,
#                 1.0,
#                 2.0
#             ],
#             "metadata": {
#                 "model": "sklearn.tree._classes.DecisionTreeClassifier",
#                 "version": "1.4.1.post1"
#             },
#             "options": {
#                 "ccp_alpha": 0.0,
#                 "criterion": "gini",
#                 "max_depth": null,
#                 "max_features": "sqrt",
#                 "max_leaf_nodes": null,
#                 "min_impurity_decrease": 0.0,
#                 "min_samples_leaf": 1,
#                 "min_samples_split": 2,
#                 "min_weight_fraction_leaf": 0.0,
#                 "random_state": 2081474387,
#                 "splitter": "best"
#             },
#             "tree": {
#                 "features": 4,
#                 "max_depth": 6,
#                 "node_count": 25,
#                 "nodes": {
#                     "node_00": {
#                         "feature": 3,
#                         "impurity": 0.6639111111111111,
#                         "left": 1,
#                         "n_samples": 93,
#                         "right": 2,
#                         "threshold": 0.75,
#                         "value": [
#                             0.3,
#                             0.37333333333333335,
#                             0.32666666666666666
#                         ],
#                         "w_samples": 150.0
#                     },
#                     "node_01": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 27,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             1.0,
#                             0.0,
#                             0.0
#                         ],
#                         "w_samples": 45.0
#                     },
#                     "node_02": {
#                         "feature": 1,
#                         "impurity": 0.49777777777777776,
#                         "left": 3,
#                         "n_samples": 66,
#                         "right": 14,
#                         "threshold": 2.950000047683716,
#                         "value": [
#                             0.0,
#                             0.5333333333333333,
#                             0.4666666666666667
#                         ],
#                         "w_samples": 105.0
#                     },
#                     "node_03": {
#                         "feature": 2,
#                         "impurity": 0.4125619834710744,
#                         "left": 4,
#                         "n_samples": 35,
#                         "right": 9,
#                         "threshold": 4.950000047683716,
#                         "value": [
#                             0.0,
#                             0.7090909090909091,
#                             0.2909090909090909
#                         ],
#                         "w_samples": 55.0
#                     },
#                     "node_04": {
#                         "feature": 2,
#                         "impurity": 0.09499999999999997,
#                         "left": 5,
#                         "n_samples": 24,
#                         "right": 6,
#                         "threshold": 4.75,
#                         "value": [
#                             0.0,
#                             0.95,
#                             0.05
#                         ],
#                         "w_samples": 40.0
#                     },
#                     "node_05": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 20,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 33.0
#                     },
#                     "node_06": {
#                         "feature": 3,
#                         "impurity": 0.40816326530612246,
#                         "left": 7,
#                         "n_samples": 4,
#                         "right": 8,
#                         "threshold": 1.649999976158142,
#                         "value": [
#                             0.0,
#                             0.7142857142857143,
#                             0.2857142857142857
#                         ],
#                         "w_samples": 7.0
#                     },
#                     "node_07": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 2,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 5.0
#                     },
#                     "node_08": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 2,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 2.0
#                     },
#                     "node_09": {
#                         "feature": 3,
#                         "impurity": 0.12444444444444447,
#                         "left": 10,
#                         "n_samples": 11,
#                         "right": 13,
#                         "threshold": 1.75,
#                         "value": [
#                             0.0,
#                             0.06666666666666667,
#                             0.9333333333333333
#                         ],
#                         "w_samples": 15.0
#                     },
#                     "node_10": {
#                         "feature": 3,
#                         "impurity": 0.375,
#                         "left": 11,
#                         "n_samples": 4,
#                         "right": 12,
#                         "threshold": 1.550000011920929,
#                         "value": [
#                             0.0,
#                             0.25,
#                             0.75
#                         ],
#                         "w_samples": 4.0
#                     },
#                     "node_11": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 3,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 3.0
#                     },
#                     "node_12": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 1.0
#                     },
#                     "node_13": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 7,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 11.0
#                     },
#                     "node_14": {
#                         "feature": 3,
#                         "impurity": 0.4488,
#                         "left": 15,
#                         "n_samples": 31,
#                         "right": 16,
#                         "threshold": 1.550000011920929,
#                         "value": [
#                             0.0,
#                             0.34,
#                             0.66
#                         ],
#                         "w_samples": 50.0
#                     },
#                     "node_15": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 7,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 12.0
#                     },
#                     "node_16": {
#                         "feature": 0,
#                         "impurity": 0.2285318559556787,
#                         "left": 17,
#                         "n_samples": 24,
#                         "right": 20,
#                         "threshold": 5.950000047683716,
#                         "value": [
#                             0.0,
#                             0.13157894736842105,
#                             0.868421052631579
#                         ],
#                         "w_samples": 38.0
#                     },
#                     "node_17": {
#                         "feature": 2,
#                         "impurity": 0.4444444444444444,
#                         "left": 18,
#                         "n_samples": 2,
#                         "right": 19,
#                         "threshold": 4.950000047683716,
#                         "value": [
#                             0.0,
#                             0.6666666666666666,
#                             0.3333333333333333
#                         ],
#                         "w_samples": 3.0
#                     },
#                     "node_18": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 2.0
#                     },
#                     "node_19": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 1.0
#                     },
#                     "node_20": {
#                         "feature": 3,
#                         "impurity": 0.156734693877551,
#                         "left": 21,
#                         "n_samples": 22,
#                         "right": 24,
#                         "threshold": 1.75,
#                         "value": [
#                             0.0,
#                             0.08571428571428572,
#                             0.9142857142857143
#                         ],
#                         "w_samples": 35.0
#                     },
#                     "node_21": {
#                         "feature": 0,
#                         "impurity": 0.5,
#                         "left": 22,
#                         "n_samples": 3,
#                         "right": 23,
#                         "threshold": 6.949999809265137,
#                         "value": [
#                             0.0,
#                             0.5,
#                             0.5
#                         ],
#                         "w_samples": 6.0
#                     },
#                     "node_22": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 2,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 3.0
#                     },
#                     "node_23": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 3.0
#                     },
#                     "node_24": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 19,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 29.0
#                     }
#                 },
#                 "outputs": 1
#             }
#         },
#         "RF_Tree_001": {
#             "classes": [
#                 0.0,
#                 1.0,
#                 2.0
#             ],
#             "metadata": {
#                 "model": "sklearn.tree._classes.DecisionTreeClassifier",
#                 "version": "1.4.1.post1"
#             },
#             "options": {
#                 "ccp_alpha": 0.0,
#                 "criterion": "gini",
#                 "max_depth": null,
#                 "max_features": "sqrt",
#                 "max_leaf_nodes": null,
#                 "min_impurity_decrease": 0.0,
#                 "min_samples_leaf": 1,
#                 "min_samples_split": 2,
#                 "min_weight_fraction_leaf": 0.0,
#                 "random_state": 2097248252,
#                 "splitter": "best"
#             },
#             "tree": {
#                 "features": 4,
#                 "max_depth": 5,
#                 "node_count": 15,
#                 "nodes": {
#                     "node_00": {
#                         "feature": 3,
#                         "impurity": 0.6624,
#                         "left": 1,
#                         "n_samples": 94,
#                         "right": 2,
#                         "threshold": 0.800000011920929,
#                         "value": [
#                             0.36,
#                             0.36,
#                             0.28
#                         ],
#                         "w_samples": 150.0
#                     },
#                     "node_01": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 31,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             1.0,
#                             0.0,
#                             0.0
#                         ],
#                         "w_samples": 54.0
#                     },
#                     "node_02": {
#                         "feature": 3,
#                         "impurity": 0.4921875,
#                         "left": 3,
#                         "n_samples": 63,
#                         "right": 10,
#                         "threshold": 1.699999988079071,
#                         "value": [
#                             0.0,
#                             0.5625,
#                             0.4375
#                         ],
#                         "w_samples": 96.0
#                     },
#                     "node_03": {
#                         "feature": 3,
#                         "impurity": 0.07008264462809921,
#                         "left": 4,
#                         "n_samples": 35,
#                         "right": 5,
#                         "threshold": 1.3499999642372131,
#                         "value": [
#                             0.0,
#                             0.9636363636363636,
#                             0.03636363636363636
#                         ],
#                         "w_samples": 55.0
#                     },
#                     "node_04": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 18,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 32.0
#                     },
#                     "node_05": {
#                         "feature": 1,
#                         "impurity": 0.1587901701323251,
#                         "left": 6,
#                         "n_samples": 17,
#                         "right": 9,
#                         "threshold": 2.649999976158142,
#                         "value": [
#                             0.0,
#                             0.9130434782608695,
#                             0.08695652173913043
#                         ],
#                         "w_samples": 23.0
#                     },
#                     "node_06": {
#                         "feature": 0,
#                         "impurity": 0.4444444444444444,
#                         "left": 7,
#                         "n_samples": 4,
#                         "right": 8,
#                         "threshold": 6.1499998569488525,
#                         "value": [
#                             0.0,
#                             0.6666666666666666,
#                             0.3333333333333333
#                         ],
#                         "w_samples": 6.0
#                     },
#                     "node_07": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 2,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 2.0
#                     },
#                     "node_08": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 2,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 4.0
#                     },
#                     "node_09": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 13,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 17.0
#                     },
#                     "node_10": {
#                         "feature": 0,
#                         "impurity": 0.04759071980963714,
#                         "left": 11,
#                         "n_samples": 28,
#                         "right": 14,
#                         "threshold": 6.0,
#                         "value": [
#                             0.0,
#                             0.024390243902439025,
#                             0.975609756097561
#                         ],
#                         "w_samples": 41.0
#                     },
#                     "node_11": {
#                         "feature": 2,
#                         "impurity": 0.31999999999999995,
#                         "left": 12,
#                         "n_samples": 5,
#                         "right": 13,
#                         "threshold": 4.900000095367432,
#                         "value": [
#                             0.0,
#                             0.2,
#                             0.8
#                         ],
#                         "w_samples": 5.0
#                     },
#                     "node_12": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 1.0
#                     },
#                     "node_13": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 4,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 4.0
#                     },
#                     "node_14": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 23,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 36.0
#                     }
#                 },
#                 "outputs": 1
#             }
#         },
#         "RF_Tree_002": {
#             "classes": [
#                 0.0,
#                 1.0,
#                 2.0
#             ],
#             "metadata": {
#                 "model": "sklearn.tree._classes.DecisionTreeClassifier",
#                 "version": "1.4.1.post1"
#             },
#             "options": {
#                 "ccp_alpha": 0.0,
#                 "criterion": "gini",
#                 "max_depth": null,
#                 "max_features": "sqrt",
#                 "max_leaf_nodes": null,
#                 "min_impurity_decrease": 0.0,
#                 "min_samples_leaf": 1,
#                 "min_samples_split": 2,
#                 "min_weight_fraction_leaf": 0.0,
#                 "random_state": 1378654752,
#                 "splitter": "best"
#             },
#             "tree": {
#                 "features": 4,
#                 "max_depth": 4,
#                 "node_count": 9,
#                 "nodes": {
#                     "node_0": {
#                         "feature": 2,
#                         "impurity": 0.6652444444444445,
#                         "left": 1,
#                         "n_samples": 91,
#                         "right": 2,
#                         "threshold": 2.449999988079071,
#                         "value": [
#                             0.36,
#                             0.3333333333333333,
#                             0.30666666666666664
#                         ],
#                         "w_samples": 150.0
#                     },
#                     "node_1": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 29,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             1.0,
#                             0.0,
#                             0.0
#                         ],
#                         "w_samples": 54.0
#                     },
#                     "node_2": {
#                         "feature": 3,
#                         "impurity": 0.4991319444444444,
#                         "left": 3,
#                         "n_samples": 62,
#                         "right": 8,
#                         "threshold": 1.6500000357627869,
#                         "value": [
#                             0.0,
#                             0.5208333333333334,
#                             0.4791666666666667
#                         ],
#                         "w_samples": 96.0
#                     },
#                     "node_3": {
#                         "feature": 0,
#                         "impurity": 0.03844675124951946,
#                         "left": 4,
#                         "n_samples": 34,
#                         "right": 5,
#                         "threshold": 6.049999952316284,
#                         "value": [
#                             0.0,
#                             0.9803921568627451,
#                             0.0196078431372549
#                         ],
#                         "w_samples": 51.0
#                     },
#                     "node_4": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 19,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 29.0
#                     },
#                     "node_5": {
#                         "feature": 2,
#                         "impurity": 0.08677685950413228,
#                         "left": 6,
#                         "n_samples": 15,
#                         "right": 7,
#                         "threshold": 5.25,
#                         "value": [
#                             0.0,
#                             0.9545454545454546,
#                             0.045454545454545456
#                         ],
#                         "w_samples": 22.0
#                     },
#                     "node_6": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 14,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 21.0
#                     },
#                     "node_7": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 1.0
#                     },
#                     "node_8": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 28,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 45.0
#                     }
#                 },
#                 "outputs": 1
#             }
#         },
#         "RF_Tree_003": {
#             "classes": [
#                 0.0,
#                 1.0,
#                 2.0
#             ],
#             "metadata": {
#                 "model": "sklearn.tree._classes.DecisionTreeClassifier",
#                 "version": "1.4.1.post1"
#             },
#             "options": {
#                 "ccp_alpha": 0.0,
#                 "criterion": "gini",
#                 "max_depth": null,
#                 "max_features": "sqrt",
#                 "max_leaf_nodes": null,
#                 "min_impurity_decrease": 0.0,
#                 "min_samples_leaf": 1,
#                 "min_samples_split": 2,
#                 "min_weight_fraction_leaf": 0.0,
#                 "random_state": 1021782806,
#                 "splitter": "best"
#             },
#             "tree": {
#                 "features": 4,
#                 "max_depth": 7,
#                 "node_count": 21,
#                 "nodes": {
#                     "node_00": {
#                         "feature": 3,
#                         "impurity": 0.6568,
#                         "left": 1,
#                         "n_samples": 94,
#                         "right": 2,
#                         "threshold": 0.800000011920929,
#                         "value": [
#                             0.32666666666666666,
#                             0.26666666666666666,
#                             0.4066666666666667
#                         ],
#                         "w_samples": 150.0
#                     },
#                     "node_01": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 30,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             1.0,
#                             0.0,
#                             0.0
#                         ],
#                         "w_samples": 49.0
#                     },
#                     "node_02": {
#                         "feature": 2,
#                         "impurity": 0.47838447211057744,
#                         "left": 3,
#                         "n_samples": 64,
#                         "right": 6,
#                         "threshold": 4.75,
#                         "value": [
#                             0.0,
#                             0.39603960396039606,
#                             0.6039603960396039
#                         ],
#                         "w_samples": 101.0
#                     },
#                     "node_03": {
#                         "feature": 3,
#                         "impurity": 0.1022644265887509,
#                         "left": 4,
#                         "n_samples": 27,
#                         "right": 5,
#                         "threshold": 1.6500000357627869,
#                         "value": [
#                             0.0,
#                             0.9459459459459459,
#                             0.05405405405405406
#                         ],
#                         "w_samples": 37.0
#                     },
#                     "node_04": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 26,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 35.0
#                     },
#                     "node_05": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 2.0
#                     },
#                     "node_06": {
#                         "feature": 0,
#                         "impurity": 0.14404296875,
#                         "left": 7,
#                         "n_samples": 37,
#                         "right": 16,
#                         "threshold": 6.049999952316284,
#                         "value": [
#                             0.0,
#                             0.078125,
#                             0.921875
#                         ],
#                         "w_samples": 64.0
#                     },
#                     "node_07": {
#                         "feature": 3,
#                         "impurity": 0.42603550295857984,
#                         "left": 8,
#                         "n_samples": 7,
#                         "right": 9,
#                         "threshold": 1.550000011920929,
#                         "value": [
#                             0.0,
#                             0.3076923076923077,
#                             0.6923076923076923
#                         ],
#                         "w_samples": 13.0
#                     },
#                     "node_08": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 4.0
#                     },
#                     "node_09": {
#                         "feature": 0,
#                         "impurity": 0.49382716049382713,
#                         "left": 10,
#                         "n_samples": 6,
#                         "right": 11,
#                         "threshold": 5.8500001430511475,
#                         "value": [
#                             0.0,
#                             0.4444444444444444,
#                             0.5555555555555556
#                         ],
#                         "w_samples": 9.0
#                     },
#                     "node_10": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 3,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 4.0
#                     },
#                     "node_11": {
#                         "feature": 1,
#                         "impurity": 0.31999999999999995,
#                         "left": 12,
#                         "n_samples": 3,
#                         "right": 13,
#                         "threshold": 2.850000023841858,
#                         "value": [
#                             0.0,
#                             0.8,
#                             0.2
#                         ],
#                         "w_samples": 5.0
#                     },
#                     "node_12": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 3.0
#                     },
#                     "node_13": {
#                         "feature": 1,
#                         "impurity": 0.5,
#                         "left": 14,
#                         "n_samples": 2,
#                         "right": 15,
#                         "threshold": 3.100000023841858,
#                         "value": [
#                             0.0,
#                             0.5,
#                             0.5
#                         ],
#                         "w_samples": 2.0
#                     },
#                     "node_14": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 1.0
#                     },
#                     "node_15": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 1.0
#                     },
#                     "node_16": {
#                         "feature": 1,
#                         "impurity": 0.03844675124951946,
#                         "left": 17,
#                         "n_samples": 30,
#                         "right": 20,
#                         "threshold": 2.549999952316284,
#                         "value": [
#                             0.0,
#                             0.0196078431372549,
#                             0.9803921568627451
#                         ],
#                         "w_samples": 51.0
#                     },
#                     "node_17": {
#                         "feature": 3,
#                         "impurity": 0.5,
#                         "left": 18,
#                         "n_samples": 2,
#                         "right": 19,
#                         "threshold": 1.649999976158142,
#                         "value": [
#                             0.0,
#                             0.5,
#                             0.5
#                         ],
#                         "w_samples": 2.0
#                     },
#                     "node_18": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 1.0
#                     },
#                     "node_19": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 1.0
#                     },
#                     "node_20": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 28,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 49.0
#                     }
#                 },
#                 "outputs": 1
#             }
#         },
#         "RF_Tree_004": {
#             "classes": [
#                 0.0,
#                 1.0,
#                 2.0
#             ],
#             "metadata": {
#                 "model": "sklearn.tree._classes.DecisionTreeClassifier",
#                 "version": "1.4.1.post1"
#             },
#             "options": {
#                 "ccp_alpha": 0.0,
#                 "criterion": "gini",
#                 "max_depth": null,
#                 "max_features": "sqrt",
#                 "max_leaf_nodes": null,
#                 "min_impurity_decrease": 0.0,
#                 "min_samples_leaf": 1,
#                 "min_samples_split": 2,
#                 "min_weight_fraction_leaf": 0.0,
#                 "random_state": 1661969331,
#                 "splitter": "best"
#             },
#             "tree": {
#                 "features": 4,
#                 "max_depth": 5,
#                 "node_count": 15,
#                 "nodes": {
#                     "node_00": {
#                         "feature": 2,
#                         "impurity": 0.6528,
#                         "left": 1,
#                         "n_samples": 90,
#                         "right": 2,
#                         "threshold": 2.599999964237213,
#                         "value": [
#                             0.24,
#                             0.4,
#                             0.36
#                         ],
#                         "w_samples": 150.0
#                     },
#                     "node_01": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 26,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             1.0,
#                             0.0,
#                             0.0
#                         ],
#                         "w_samples": 36.0
#                     },
#                     "node_02": {
#                         "feature": 2,
#                         "impurity": 0.4986149584487535,
#                         "left": 3,
#                         "n_samples": 64,
#                         "right": 8,
#                         "threshold": 4.950000047683716,
#                         "value": [
#                             0.0,
#                             0.5263157894736842,
#                             0.47368421052631576
#                         ],
#                         "w_samples": 114.0
#                     },
#                     "node_03": {
#                         "feature": 3,
#                         "impurity": 0.21585798816568047,
#                         "left": 4,
#                         "n_samples": 32,
#                         "right": 5,
#                         "threshold": 1.600000023841858,
#                         "value": [
#                             0.0,
#                             0.8769230769230769,
#                             0.12307692307692308
#                         ],
#                         "w_samples": 65.0
#                     },
#                     "node_04": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 26,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 52.0
#                     },
#                     "node_05": {
#                         "feature": 1,
#                         "impurity": 0.47337278106508873,
#                         "left": 6,
#                         "n_samples": 6,
#                         "right": 7,
#                         "threshold": 3.100000023841858,
#                         "value": [
#                             0.0,
#                             0.38461538461538464,
#                             0.6153846153846154
#                         ],
#                         "w_samples": 13.0
#                     },
#                     "node_06": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 5,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 8.0
#                     },
#                     "node_07": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 5.0
#                     },
#                     "node_08": {
#                         "feature": 3,
#                         "impurity": 0.1149521032902957,
#                         "left": 9,
#                         "n_samples": 32,
#                         "right": 14,
#                         "threshold": 1.75,
#                         "value": [
#                             0.0,
#                             0.061224489795918366,
#                             0.9387755102040817
#                         ],
#                         "w_samples": 49.0
#                     },
#                     "node_09": {
#                         "feature": 0,
#                         "impurity": 0.5,
#                         "left": 10,
#                         "n_samples": 4,
#                         "right": 13,
#                         "threshold": 6.949999809265137,
#                         "value": [
#                             0.0,
#                             0.5,
#                             0.5
#                         ],
#                         "w_samples": 6.0
#                     },
#                     "node_10": {
#                         "feature": 1,
#                         "impurity": 0.48,
#                         "left": 11,
#                         "n_samples": 3,
#                         "right": 12,
#                         "threshold": 2.450000047683716,
#                         "value": [
#                             0.0,
#                             0.6,
#                             0.4
#                         ],
#                         "w_samples": 5.0
#                     },
#                     "node_11": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 2.0
#                     },
#                     "node_12": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 2,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 3.0
#                     },
#                     "node_13": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
# ...
#                     },
#                     "node_11": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 2.0
#                     },
#                     "node_12": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 2.0
#                     },
#                     "node_13": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 3.0
#                     },
#                     "node_14": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 19,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 36.0
#                     }
#                 },
#                 "outputs": 1
#             }
#         },
#         "RF_Tree_098": {
#             "classes": [
#                 0.0,
#                 1.0,
#                 2.0
#             ],
#             "metadata": {
#                 "model": "sklearn.tree._classes.DecisionTreeClassifier",
#                 "version": "1.4.1.post1"
#             },
#             "options": {
#                 "ccp_alpha": 0.0,
#                 "criterion": "gini",
#                 "max_depth": null,
#                 "max_features": "sqrt",
#                 "max_leaf_nodes": null,
#                 "min_impurity_decrease": 0.0,
#                 "min_samples_leaf": 1,
#                 "min_samples_split": 2,
#                 "min_weight_fraction_leaf": 0.0,
#                 "random_state": 1200080321,
#                 "splitter": "best"
#             },
#             "tree": {
#                 "features": 4,
#                 "max_depth": 6,
#                 "node_count": 13,
#                 "nodes": {
#                     "node_00": {
#                         "feature": 2,
#                         "impurity": 0.6628444444444445,
#                         "left": 1,
#                         "n_samples": 89,
#                         "right": 2,
#                         "threshold": 2.599999964237213,
#                         "value": [
#                             0.37333333333333335,
#                             0.2866666666666667,
#                             0.34
#                         ],
#                         "w_samples": 150.0
#                     },
#                     "node_01": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 32,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             1.0,
#                             0.0,
#                             0.0
#                         ],
#                         "w_samples": 56.0
#                     },
#                     "node_02": {
#                         "feature": 2,
#                         "impurity": 0.49637845178813944,
#                         "left": 3,
#                         "n_samples": 57,
#                         "right": 4,
#                         "threshold": 4.75,
#                         "value": [
#                             0.0,
#                             0.4574468085106383,
#                             0.5425531914893617
#                         ],
#                         "w_samples": 94.0
#                     },
#                     "node_03": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 24,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 36.0
#                     },
#                     "node_04": {
#                         "feature": 3,
#                         "impurity": 0.21224732461355533,
#                         "left": 5,
#                         "n_samples": 33,
#                         "right": 12,
#                         "threshold": 1.75,
#                         "value": [
#                             0.0,
#                             0.1206896551724138,
#                             0.8793103448275862
#                         ],
#                         "w_samples": 58.0
#                     },
#                     "node_05": {
#                         "feature": 1,
#                         "impurity": 0.345679012345679,
#                         "left": 6,
#                         "n_samples": 7,
#                         "right": 11,
#                         "threshold": 2.649999976158142,
#                         "value": [
#                             0.0,
#                             0.7777777777777778,
#                             0.2222222222222222
#                         ],
#                         "w_samples": 9.0
#                     },
#                     "node_06": {
#                         "feature": 3,
#                         "impurity": 0.4444444444444444,
#                         "left": 7,
#                         "n_samples": 3,
#                         "right": 8,
#                         "threshold": 1.449999988079071,
#                         "value": [
#                             0.0,
#                             0.3333333333333333,
#                             0.6666666666666666
#                         ],
#                         "w_samples": 3.0
#                     },
#                     "node_07": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 1.0
#                     },
#                     "node_08": {
#                         "feature": 0,
#                         "impurity": 0.5,
#                         "left": 9,
#                         "n_samples": 2,
#                         "right": 10,
#                         "threshold": 6.150000095367432,
#                         "value": [
#                             0.0,
#                             0.5,
#                             0.5
#                         ],
#                         "w_samples": 2.0
#                     },
#                     "node_09": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 1.0
#                     },
#                     "node_10": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 1.0
#                     },
#                     "node_11": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 4,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 6.0
#                     },
#                     "node_12": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 26,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 49.0
#                     }
#                 },
#                 "outputs": 1
#             }
#         },
#         "RF_Tree_099": {
#             "classes": [
#                 0.0,
#                 1.0,
#                 2.0
#             ],
#             "metadata": {
#                 "model": "sklearn.tree._classes.DecisionTreeClassifier",
#                 "version": "1.4.1.post1"
#             },
#             "options": {
#                 "ccp_alpha": 0.0,
#                 "criterion": "gini",
#                 "max_depth": null,
#                 "max_features": "sqrt",
#                 "max_leaf_nodes": null,
#                 "min_impurity_decrease": 0.0,
#                 "min_samples_leaf": 1,
#                 "min_samples_split": 2,
#                 "min_weight_fraction_leaf": 0.0,
#                 "random_state": 450836718,
#                 "splitter": "best"
#             },
#             "tree": {
#                 "features": 4,
#                 "max_depth": 4,
#                 "node_count": 9,
#                 "nodes": {
#                     "node_0": {
#                         "feature": 3,
#                         "impurity": 0.6664,
#                         "left": 1,
#                         "n_samples": 98,
#                         "right": 2,
#                         "threshold": 0.800000011920929,
#                         "value": [
#                             0.32,
#                             0.34,
#                             0.34
#                         ],
#                         "w_samples": 150.0
#                     },
#                     "node_1": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 33,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             1.0,
#                             0.0,
#                             0.0
#                         ],
#                         "w_samples": 48.0
#                     },
#                     "node_2": {
#                         "feature": 3,
#                         "impurity": 0.5,
#                         "left": 3,
#                         "n_samples": 65,
#                         "right": 8,
#                         "threshold": 1.6500000357627869,
#                         "value": [
#                             0.0,
#                             0.5,
#                             0.5
#                         ],
#                         "w_samples": 102.0
#                     },
#                     "node_3": {
#                         "feature": 2,
#                         "impurity": 0.13487603305785123,
#                         "left": 4,
#                         "n_samples": 33,
#                         "right": 5,
#                         "threshold": 4.950000047683716,
#                         "value": [
#                             0.0,
#                             0.9272727272727272,
#                             0.07272727272727272
#                         ],
#                         "w_samples": 55.0
#                     },
#                     "node_4": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 30,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 50.0
#                     },
#                     "node_5": {
#                         "feature": 3,
#                         "impurity": 0.31999999999999995,
#                         "left": 6,
#                         "n_samples": 3,
#                         "right": 7,
#                         "threshold": 1.550000011920929,
#                         "value": [
#                             0.0,
#                             0.2,
#                             0.8
#                         ],
#                         "w_samples": 5.0
#                     },
#                     "node_6": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 2,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 4.0
#                     },
#                     "node_7": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 1,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             1.0,
#                             0.0
#                         ],
#                         "w_samples": 1.0
#                     },
#                     "node_8": {
#                         "feature": null,
#                         "impurity": 0.0,
#                         "left": null,
#                         "n_samples": 32,
#                         "right": null,
#                         "threshold": null,
#                         "value": [
#                             0.0,
#                             0.0,
#                             1.0
#                         ],
#                         "w_samples": 47.0
#                     }
#                 },
#                 "outputs": 1
#             }
#         },
#         "Trees": 100
#     },
#     "metadata": {
#         "model": "sklearn.ensemble._forest.RandomForestClassifier",
#         "version": "1.4.1.post1"
#     },
#     "options": {
#         "ccp_alpha": 0.0,
#         "class_weight": null,
#         "criterion": "gini",
#         "max_depth": null,
#         "max_features": "sqrt",
#         "max_leaf_nodes": null,
#         "max_samples": null,
#         "min_impurity_decrease": 0.0,
#         "min_samples_leaf": 1,
#         "min_samples_split": 2,
#         "min_weight_fraction_leaf": 0.0,
#         "n_estimators": 100,
#         "n_jobs": null,
#         "random_state": null
#     }
# }
