# %%
import json 

from sklearn.datasets import load_iris
import xgboost as xgb

from sklearn.tree import DecisionTreeClassifier
 
clf = xgb.XGBClassifier()
iris = load_iris()

# %%
clf.fit(iris.data, iris.target)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
import sklearn2json

# %%
import numpy as np



class NumpyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        return super(NumpyEncoder, self).default(obj)

# %%
lDict = sklearn2json.convert_model(clf)

lJSON = json.dumps(lDict, cls=NumpyEncoder, sort_keys= True, indent = 4)
# Out:
# CONVERT_MODEL  <class 'xgboost.sklearn.XGBClassifier'>
# {
#     "learner": {
#         "generic_param": {
#             "device": "cpu",
#             "fail_on_invalid_gpu_id": "0",
#             "n_jobs": "0",
#             "nthread": "0",
#             "random_state": "0",
#             "seed": "0",
#             "seed_per_iteration": "0",
#             "validate_parameters": "1"
#         },
#         "gradient_booster": {
#             "gbtree_model_param": {
#                 "num_parallel_tree": "1",
#                 "num_trees": "300"
#             },
#             "gbtree_train_param": {
#                 "process_type": "default",
#                 "tree_method": "auto",
#                 "updater": "grow_quantile_histmaker",
#                 "updater_seq": "grow_quantile_histmaker"
#             },
#             "name": "gbtree",
#             "specified_updater": false,
#             "tree_train_param": {
#                 "alpha": "0",
#                 "cache_opt": "1",
#                 "colsample_bylevel": "1",
#                 "colsample_bynode": "1",
#                 "colsample_bytree": "1",
#                 "eta": "0.300000012",
#                 "gamma": "0",
#                 "grow_policy": "depthwise",
#                 "interaction_constraints": "",
#                 "lambda": "1",
#                 "learning_rate": "0.300000012",
#                 "max_bin": "256",
#                 "max_cat_threshold": "64",
#                 "max_cat_to_onehot": "4",
#                 "max_delta_step": "0",
#                 "max_depth": "6",
#                 "max_leaves": "0",
#                 "min_child_weight": "1",
#                 "min_split_loss": "0",
#                 "monotone_constraints": "()",
#                 "refresh_leaf": "1",
#                 "reg_alpha": "0",
#                 "reg_lambda": "1",
#                 "sampling_method": "uniform",
#                 "sketch_ratio": "2",
#                 "sparse_threshold": "0.20000000000000001",
#                 "subsample": "1"
#             },
#             "updater": [
#                 {
#                     "hist_train_param": {
#                         "debug_synchronize": "0",
#                         "max_cached_hist_node": "65536"
#                     },
#                     "name": "grow_quantile_histmaker"
#                 }
#             ]
#         },
#         "learner_model_param": {
#             "base_score": "5E-1",
#             "boost_from_average": "1",
#             "num_class": "3",
#             "num_feature": "4",
#             "num_target": "1"
#         },
#         "learner_train_param": {
#             "booster": "gbtree",
#             "disable_default_eval_metric": "0",
#             "multi_strategy": "one_output_per_tree",
#             "objective": "multi:softprob"
#         },
#         "metrics": [
#             {
#                 "name": "mlogloss"
#             }
#         ],
#         "objective": {
#             "name": "multi:softprob",
#             "softmax_multiclass_param": {
#                 "num_class": "3"
#             }
#         }
#     },
#     "version": [
#         2,
#         0,
#         3
#     ]
# }
# {'learner': {'generic_param': {'device': 'cpu', 'fail_on_invalid_gpu_id': '0', 'n_jobs': '0', 'nthread': '0', 'random_state': '0', 'seed': '0', 'seed_per_iteration': '0', 'validate_parameters': '1'}, 'gradient_booster': {'gbtree_model_param': {'num_parallel_tree': '1', 'num_trees': '300'}, 'gbtree_train_param': {'process_type': 'default', 'tree_method': 'auto', 'updater': 'grow_quantile_histmaker', 'updater_seq': 'grow_quantile_histmaker'}, 'name': 'gbtree', 'specified_updater': False, 'tree_train_param': {'alpha': '0', 'cache_opt': '1', 'colsample_bylevel': '1', 'colsample_bynode': '1', 'colsample_bytree': '1', 'eta': '0.300000012', 'gamma': '0', 'grow_policy': 'depthwise', 'interaction_constraints': '', 'lambda': '1', 'learning_rate': '0.300000012', 'max_bin': '256', 'max_cat_threshold': '64', 'max_cat_to_onehot': '4', 'max_delta_step': '0', 'max_depth': '6', 'max_leaves': '0', 'min_child_weight': '1', 'min_split_loss': '0', 'monotone_constraints': '()', 'refresh_leaf': '1', 'reg_alpha': '0', 'reg_lambda': '1', 'sampling_method': 'uniform', 'sketch_ratio': '2', 'sparse_threshold': '0.20000000000000001', 'subsample': '1'}, 'updater': [{'hist_train_param': {'debug_synchronize': '0', 'max_cached_hist_node': '65536'}, 'name': 'grow_quantile_histmaker'}]}, 'learner_model_param': {'base_score': '5E-1', 'boost_from_average': '1', 'num_class': '3', 'num_feature': '4', 'num_target': '1'}, 'learner_train_param': {'booster': 'gbtree', 'disable_default_eval_metric': '0', 'multi_strategy': 'one_output_per_tree', 'objective': 'multi:softprob'}, 'metrics': [{'name': 'mlogloss'}], 'objective': {'name': 'multi:softprob', 'softmax_multiclass_param': {'num_class': '3'}}}, 'version': [2, 0, 3]}

# %%
print(lJSON)
# Out:
# {
#     "booster": {
#         "BaseSCore": "5E-1",
#         "Tree_000": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.430622011
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.220048919
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_001": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     -0.215311036
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.79999995
#             },
#             "Node_03": {
#                 "leaf_value": [],
#                 "left": 5,
#                 "parent": 2,
#                 "right": 6,
#                 "sindex": 2,
#                 "svalue": 5.0
#             },
#             "Node_04": {
#                 "leaf_value": [],
#                 "left": 7,
#                 "parent": 2,
#                 "right": 8,
#                 "sindex": 2,
#                 "svalue": 4.9000001
#             },
#             "Node_05": {
#                 "leaf_value": [],
#                 "left": 9,
#                 "parent": 3,
#                 "right": 10,
#                 "sindex": 3,
#                 "svalue": 1.60000002
#             },
#             "Node_06": {
#                 "leaf_value": [],
#                 "left": 11,
#                 "parent": 3,
#                 "right": 12,
#                 "sindex": 3,
#                 "svalue": 1.60000002
#             },
#             "Node_07": {
#                 "leaf_value": [
#                     -7.66345476e-09
#                 ],
#                 "left": null,
#                 "parent": 4,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_08": {
#                 "leaf_value": [
#                     -0.213812172
#                 ],
#                 "left": null,
#                 "parent": 4,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_09": {
#                 "leaf_value": [
#                     0.428571463
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_10": {
#                 "leaf_value": [
#                     0.128571421
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_11": {
#                 "leaf_value": [
#                     -0.128571451
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_12": {
#                 "leaf_value": [
#                     0.128571421
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_002": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 3,
#                 "svalue": 1.70000005
#             },
#             "Node_01": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 2,
#                 "svalue": 5.0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     0.402985066
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_03": {
#                 "leaf_value": [
#                     -0.219899267
#                 ],
#                 "left": null,
#                 "parent": 1,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_04": {
#                 "leaf_value": [
#                     0.217241377
#                 ],
#                 "left": null,
#                 "parent": 1,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_003": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.295082778
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.19683747
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_004": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     -0.191612214
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.79999995
#             },
#             "Node_03": {
#                 "leaf_value": [],
#                 "left": 5,
#                 "parent": 2,
#                 "right": 6,
#                 "sindex": 2,
#                 "svalue": 5.0
#             },
#             "Node_04": {
#                 "leaf_value": [],
#                 "left": 7,
#                 "parent": 2,
#                 "right": 8,
#                 "sindex": 2,
#                 "svalue": 4.9000001
#             },
#             "Node_05": {
#                 "leaf_value": [
#                     0.287215412
#                 ],
#                 "left": null,
#                 "parent": 3,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_06": {
#                 "leaf_value": [],
#                 "left": 9,
#                 "parent": 3,
#                 "right": 10,
#                 "sindex": 3,
#                 "svalue": 1.60000002
#             },
#             "Node_07": {
#                 "leaf_value": [
#                     0.0119826663
#                 ],
#                 "left": null,
#                 "parent": 4,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_08": {
#                 "leaf_value": [
#                     -0.191138521
#                 ],
#                 "left": null,
#                 "parent": 4,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_09": {
#                 "leaf_value": [
#                     -0.119655393
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_10": {
#                 "leaf_value": [
#                     0.121238194
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_005": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 4.80000019
#             },
#             "Node_01": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.60000002
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 5,
#                 "parent": 0,
#                 "right": 6,
#                 "sindex": 3,
#                 "svalue": 1.79999995
#             },
#             "Node_03": {
#                 "leaf_value": [
#                     -0.195821807
#                 ],
#                 "left": null,
#                 "parent": 1,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_04": {
#                 "leaf_value": [
#                     -0.00269367103
#                 ],
#                 "left": null,
#                 "parent": 1,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_05": {
#                 "leaf_value": [],
#                 "left": 7,
#                 "parent": 2,
#                 "right": 8,
#                 "sindex": 2,
#                 "svalue": 5.0
#             },
#             "Node_06": {
#                 "leaf_value": [],
#                 "left": 9,
#                 "parent": 2,
#                 "right": 10,
#                 "sindex": 2,
#                 "svalue": 4.9000001
#             },
#             "Node_07": {
#                 "leaf_value": [
#                     -0.107412621
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_08": {
#                 "leaf_value": [],
#                 "left": 11,
#                 "parent": 5,
#                 "right": 12,
#                 "sindex": 3,
#                 "svalue": 1.60000002
#             },
#             "Node_09": {
#                 "leaf_value": [
#                     0.0771064013
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_10": {
#                 "leaf_value": [
#                     0.297540128
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_11": {
#                 "leaf_value": [
#                     0.209871635
#                 ],
#                 "left": null,
#                 "parent": 8,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_12": {
#                 "leaf_value": [
#                     -0.0265715588
#                 ],
#                 "left": null,
#                 "parent": 8,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_006": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.236306787
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.181336597
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_007": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     -0.175504029
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.79999995
#             },
#             "Node_03": {
#                 "leaf_value": [],
#                 "left": 5,
#                 "parent": 2,
#                 "right": 6,
#                 "sindex": 2,
#                 "svalue": 5.0999999
#             },
#             "Node_04": {
#                 "leaf_value": [],
#                 "left": 7,
#                 "parent": 2,
#                 "right": 8,
#                 "sindex": 2,
#                 "svalue": 4.9000001
#             },
#             "Node_05": {
#                 "leaf_value": [],
#                 "left": 9,
#                 "parent": 3,
#                 "right": 10,
#                 "sindex": 0,
#                 "svalue": 5.0999999
#             },
#             "Node_06": {
#                 "leaf_value": [
#                     -0.0371556394
#                 ],
#                 "left": null,
#                 "parent": 3,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_07": {
#                 "leaf_value": [
#                     0.0100614149
#                 ],
#                 "left": null,
#                 "parent": 4,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_08": {
#                 "leaf_value": [
#                     -0.174704418
#                 ],
#                 "left": null,
#                 "parent": 4,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_09": {
#                 "leaf_value": [
#                     0.0784917325
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_10": {
#                 "leaf_value": [],
#                 "left": 11,
#                 "parent": 5,
#                 "right": 12,
#                 "sindex": 1,
#                 "svalue": 2.29999995
#             },
#             "Node_11": {
#                 "leaf_value": [
#                     0.0668418482
#                 ],
#                 "left": null,
#                 "parent": 10,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_12": {
#                 "leaf_value": [
#                     0.241057426
#                 ],
#                 "left": null,
#                 "parent": 10,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_008": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 4.80000019
#             },
#             "Node_01": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.60000002
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 5,
#                 "parent": 0,
#                 "right": 6,
#                 "sindex": 3,
#                 "svalue": 1.79999995
#             },
#             "Node_03": {
#                 "leaf_value": [
#                     -0.180165544
#                 ],
#                 "left": null,
#                 "parent": 1,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_04": {
#                 "leaf_value": [
#                     0.00726488465
#                 ],
#                 "left": null,
#                 "parent": 1,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_05": {
#                 "leaf_value": [],
#                 "left": 7,
#                 "parent": 2,
#                 "right": 8,
#                 "sindex": 2,
#                 "svalue": 5.0999999
#             },
#             "Node_06": {
#                 "leaf_value": [],
#                 "left": 9,
#                 "parent": 2,
#                 "right": 10,
#                 "sindex": 2,
#                 "svalue": 4.9000001
#             },
#             "Node_07": {
#                 "leaf_value": [
#                     -0.0578227639
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_08": {
#                 "leaf_value": [
#                     0.122338183
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_09": {
#                 "leaf_value": [
#                     0.0630181506
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_10": {
#                 "leaf_value": [
#                     0.237204403
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_009": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.203852341
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.170494914
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_010": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     -0.163605615
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.79999995
#             },
#             "Node_03": {
#                 "leaf_value": [],
#                 "left": 5,
#                 "parent": 2,
#                 "right": 6,
#                 "sindex": 2,
#                 "svalue": 5.0
#             },
#             "Node_04": {
#                 "leaf_value": [],
#                 "left": 7,
#                 "parent": 2,
#                 "right": 8,
#                 "sindex": 2,
#                 "svalue": 4.9000001
#             },
#             "Node_05": {
#                 "leaf_value": [],
#                 "left": 9,
#                 "parent": 3,
#                 "right": 10,
#                 "sindex": 3,
#                 "svalue": 1.60000002
#             },
#             "Node_06": {
#                 "leaf_value": [],
#                 "left": 11,
#                 "parent": 3,
#                 "right": 12,
#                 "sindex": 3,
#                 "svalue": 1.60000002
#             },
#             "Node_07": {
#                 "leaf_value": [
#                     0.0090344632
#                 ],
#                 "left": null,
#                 "parent": 4,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_08": {
#                 "leaf_value": [
#                     -0.162477046
#                 ],
#                 "left": null,
#                 "parent": 4,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_09": {
#                 "leaf_value": [
#                     0.204518631
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_10": {
#                 "leaf_value": [
#                     0.0464834869
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_11": {
#                 "leaf_value": [
#                     -0.109693311
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_12": {
#                 "leaf_value": [
#                     0.0926420242
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_011": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 4.80000019
#             },
#             "Node_01": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.60000002
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 5,
#                 "parent": 0,
#                 "right": 6,
#                 "sindex": 3,
#                 "svalue": 1.79999995
#             },
#             "Node_03": {
#                 "leaf_value": [
#                     -0.169104204
#                 ],
#                 "left": null,
#                 "parent": 1,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_04": {
#                 "leaf_value": [
#                     0.0137579208
#                 ],
#                 "left": null,
#                 "parent": 1,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_05": {
#                 "leaf_value": [],
#                 "left": 7,
#                 "parent": 2,
#                 "right": 8,
#                 "sindex": 2,
#                 "svalue": 5.0999999
#             },
#             "Node_06": {
#                 "leaf_value": [],
#                 "left": 9,
#                 "parent": 2,
#                 "right": 10,
#                 "sindex": 2,
#                 "svalue": 4.9000001
#             },
#             "Node_07": {
#                 "leaf_value": [
#                     -0.0452597365
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_08": {
#                 "leaf_value": [
#                     0.100356087
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_09": {
#                 "leaf_value": [
#                     0.0519054718
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_10": {
#                 "leaf_value": [
#                     0.203949228
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_012": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.183452412
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.162297457
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_013": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     -0.154138923
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.70000005
#             },
#             "Node_03": {
#                 "leaf_value": [],
#                 "left": 5,
#                 "parent": 2,
#                 "right": 6,
#                 "sindex": 2,
#                 "svalue": 5.0
#             },
#             "Node_04": {
#                 "leaf_value": [],
#                 "left": 7,
#                 "parent": 2,
#                 "right": 8,
#                 "sindex": 2,
#                 "svalue": 5.0999999
#             },
#             "Node_05": {
#                 "leaf_value": [
#                     0.186947152
#                 ],
#                 "left": null,
#                 "parent": 3,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_06": {
#                 "leaf_value": [
#                     -0.053264387
#                 ],
#                 "left": null,
#                 "parent": 3,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_07": {
#                 "leaf_value": [],
#                 "left": 9,
#                 "parent": 4,
#                 "right": 10,
#                 "sindex": 1,
#                 "svalue": 2.9000001
#             },
#             "Node_08": {
#                 "leaf_value": [
#                     -0.150662541
#                 ],
#                 "left": null,
#                 "parent": 4,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_09": {
#                 "leaf_value": [
#                     -0.135480031
#                 ],
#                 "left": null,
#                 "parent": 7,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_10": {
#                 "leaf_value": [
#                     0.0885925591
#                 ],
#                 "left": null,
#                 "parent": 7,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_014": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 4.80000019
#             },
#             "Node_01": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.60000002
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 5,
#                 "parent": 0,
#                 "right": 6,
#                 "sindex": 3,
#                 "svalue": 1.79999995
#             },
#             "Node_03": {
#                 "leaf_value": [
#                     -0.160508573
#                 ],
#                 "left": null,
#                 "parent": 1,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_04": {
#                 "leaf_value": [
#                     0.0125771537
#                 ],
#                 "left": null,
#                 "parent": 1,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_05": {
#                 "leaf_value": [],
#                 "left": 7,
#                 "parent": 2,
#                 "right": 8,
#                 "sindex": 2,
#                 "svalue": 5.0999999
#             },
#             "Node_06": {
#                 "leaf_value": [],
#                 "left": 9,
#                 "parent": 2,
#                 "right": 10,
#                 "sindex": 2,
#                 "svalue": 4.9000001
#             },
#             "Node_07": {
#                 "leaf_value": [
#                     -0.0388760455
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_08": {
#                 "leaf_value": [
#                     0.0858836025
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_09": {
#                 "leaf_value": [
#                     0.042941872
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_10": {
#                 "leaf_value": [
#                     0.183017045
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_015": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.169368118
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.155699849
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_016": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     -0.146013469
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.70000005
#             },
#             "Node_03": {
#                 "leaf_value": [],
#                 "left": 5,
#                 "parent": 2,
#                 "right": 6,
#                 "sindex": 2,
#                 "svalue": 5.0
#             },
#             "Node_04": {
#                 "leaf_value": [],
#                 "left": 7,
#                 "parent": 2,
#                 "right": 8,
#                 "sindex": 2,
#                 "svalue": 5.0999999
#             },
#             "Node_05": {
#                 "leaf_value": [
#                     0.172504574
#                 ],
#                 "left": null,
#                 "parent": 3,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_06": {
#                 "leaf_value": [
#                     -0.0471911393
#                 ],
#                 "left": null,
#                 "parent": 3,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_07": {
#                 "leaf_value": [],
#                 "left": 9,
#                 "parent": 4,
#                 "right": 10,
#                 "sindex": 1,
#                 "svalue": 2.9000001
#             },
#             "Node_08": {
#                 "leaf_value": [
#                     -0.141917035
#                 ],
#                 "left": null,
#                 "parent": 4,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_09": {
#                 "leaf_value": [
#                     -0.126944765
#                 ],
#                 "left": null,
#                 "parent": 7,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_10": {
#                 "leaf_value": [
#                     0.0799103677
#                 ],
#                 "left": null,
#                 "parent": 7,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_017": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 4.80000019
#             },
#             "Node_01": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.60000002
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 5,
#                 "parent": 0,
#                 "right": 6,
#                 "sindex": 3,
#                 "svalue": 1.79999995
#             },
#             "Node_03": {
#                 "leaf_value": [
#                     -0.153490961
#                 ],
#                 "left": null,
#                 "parent": 1,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_04": {
#                 "leaf_value": [
#                     0.0134451231
#                 ],
#                 "left": null,
#                 "parent": 1,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_05": {
#                 "leaf_value": [],
#                 "left": 7,
#                 "parent": 2,
#                 "right": 8,
#                 "sindex": 3,
#                 "svalue": 1.60000002
#             },
#             "Node_06": {
#                 "leaf_value": [],
#                 "left": 9,
#                 "parent": 2,
#                 "right": 10,
#                 "sindex": 0,
#                 "svalue": 6.0
#             },
#             "Node_07": {
#                 "leaf_value": [
#                     0.0717510283
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_08": {
#                 "leaf_value": [
#                     -0.0414980128
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_09": {
#                 "leaf_value": [],
#                 "left": 11,
#                 "parent": 6,
#                 "right": 12,
#                 "sindex": 2,
#                 "svalue": 5.0999999
#             },
#             "Node_10": {
#                 "leaf_value": [
#                     0.173987702
#                 ],
#                 "left": null,
#                 "parent": 6,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_11": {
#                 "leaf_value": [
#                     -0.028885141
#                 ],
#                 "left": null,
#                 "parent": 9,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_12": {
#                 "leaf_value": [
#                     0.0977884308
#                 ],
#                 "left": null,
#                 "parent": 9,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_018": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.158799544
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.150105298
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_019": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     -0.138523117
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.70000005
#             },
#             "Node_03": {
#                 "leaf_value": [],
#                 "left": 5,
#                 "parent": 2,
#                 "right": 6,
#                 "sindex": 2,
#                 "svalue": 5.0
#             },
#             "Node_04": {
#                 "leaf_value": [],
#                 "left": 7,
#                 "parent": 2,
#                 "right": 8,
#                 "sindex": 2,
#                 "svalue": 5.0999999
#             },
#             "Node_05": {
#                 "leaf_value": [
#                     0.161982983
#                 ],
#                 "left": null,
#                 "parent": 3,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_06": {
#                 "leaf_value": [
#                     -0.0443760864
#                 ],
#                 "left": null,
#                 "parent": 3,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_07": {
#                 "leaf_value": [],
#                 "left": 9,
#                 "parent": 4,
#                 "right": 10,
#                 "sindex": 1,
#                 "svalue": 2.9000001
#             },
#             "Node_08": {
#                 "leaf_value": [
#                     -0.133837625
#                 ],
#                 "left": null,
#                 "parent": 4,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_09": {
#                 "leaf_value": [
#                     -0.118573882
#                 ],
#                 "left": null,
#                 "parent": 7,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_10": {
#                 "leaf_value": [
#                     0.0743857473
#                 ],
#                 "left": null,
#                 "parent": 7,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_020": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 4.80000019
#             },
#             "Node_01": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.60000002
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 5,
#                 "parent": 0,
#                 "right": 6,
#                 "sindex": 2,
#                 "svalue": 5.19999981
#             },
#             "Node_03": {
#                 "leaf_value": [
#                     -0.147345766
#                 ],
#                 "left": null,
#                 "parent": 1,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_04": {
#                 "leaf_value": [
#                     0.0142603237
#                 ],
#                 "left": null,
#                 "parent": 1,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_05": {
#                 "leaf_value": [],
#                 "left": 7,
#                 "parent": 2,
#                 "right": 8,
#                 "sindex": 3,
#                 "svalue": 1.79999995
#             },
#             "Node_06": {
#                 "leaf_value": [
#                     0.163172677
#                 ],
#                 "left": null,
#                 "parent": 2,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_07": {
#                 "leaf_value": [
#                     -0.0415497161
#                 ],
#                 "left": null,
#                 "parent": 5,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_08": {
#                 "leaf_value": [],
#                 "left": 9,
#                 "parent": 5,
#                 "right": 10,
#                 "sindex": 0,
#                 "svalue": 6.0
#             },
#             "Node_09": {
#                 "leaf_value": [
#                     0.0351802632
#                 ],
#                 "left": null,
#                 "parent": 8,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_10": {
#                 "leaf_value": [
#                     0.138523564
#                 ],
#                 "left": null,
#                 "parent": 8,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_021": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.150204912
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.145044655
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_022": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 3.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     -0.131210536
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.70000005
#             },
#             "Node_03": {
#                 "leaf_value": [],
#                 "left": 5,
#                 "parent": 2,
#                 "right": 6,
#                 "sindex": 2,
#                 "svalue": 5.0
#             },
#             "Node_04": {
#                 "leaf_value": [],
#                 "left": 7,
#                 "parent": 2,
#                 "right": 8,
#                 "sindex": 2,
#                 "svalue": 5.0999999
#             },
#             "Node_05": {
#                 "leaf_value": [
#                     0.153308138
#                 ],
#                 "left": null,
#                 "parent": 3,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_06": {
#                 "leaf_value": [
#                     -0.0395669565
#                 ],
#                 "left": null,
#                 "parent": 3,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_07": {
#                 "leaf_value": [],
#                 "left": 9,
# ...
#                 "svalue": 0
#             }
#         },
#         "Tree_280": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 1,
#                 "svalue": 2.79999995
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.0120970747
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.00600560196
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_281": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 3,
#                 "svalue": 1.70000005
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     -0.0101316646
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     0.0150914779
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_282": {
#             "Node_00": {
#                 "leaf_value": [
#                     0
#                 ],
#                 "left": null,
#                 "parent": null,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_283": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 0,
#                 "svalue": 5.9000001
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     -0.0091198571
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.70000005
#             },
#             "Node_03": {
#                 "leaf_value": [
#                     -0.000330773415
#                 ],
#                 "left": null,
#                 "parent": 2,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_04": {
#                 "leaf_value": [
#                     0.0146376276
#                 ],
#                 "left": null,
#                 "parent": 2,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_284": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 1,
#                 "svalue": 2.9000001
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.0153467301
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.0116140964
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_285": {
#             "Node_00": {
#                 "leaf_value": [
#                     0
#                 ],
#                 "left": null,
#                 "parent": null,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_286": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 1,
#                 "svalue": 2.79999995
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.0122227166
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.0059719584
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_287": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 5.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     -0.0108043384
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     0.0143785747
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_288": {
#             "Node_00": {
#                 "leaf_value": [
#                     0
#                 ],
#                 "left": null,
#                 "parent": null,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_289": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 3,
#                 "svalue": 1.70000005
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.00938121881
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.00757900765
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_290": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 1,
#                 "svalue": 2.9000001
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.0142252287
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.0103512779
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_291": {
#             "Node_00": {
#                 "leaf_value": [
#                     0
#                 ],
#                 "left": null,
#                 "parent": null,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_292": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 1,
#                 "svalue": 2.79999995
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.0120470999
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.00582764344
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_293": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 3,
#                 "svalue": 1.70000005
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     -0.00955164526
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     0.0143568404
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_294": {
#             "Node_00": {
#                 "leaf_value": [
#                     0
#                 ],
#                 "left": null,
#                 "parent": null,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_295": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 0,
#                 "svalue": 5.9000001
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     -0.00876035076
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [],
#                 "left": 3,
#                 "parent": 0,
#                 "right": 4,
#                 "sindex": 3,
#                 "svalue": 1.70000005
#             },
#             "Node_03": {
#                 "leaf_value": [
#                     -0.000616947073
#                 ],
#                 "left": null,
#                 "parent": 2,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_04": {
#                 "leaf_value": [
#                     0.0146507435
#                 ],
#                 "left": null,
#                 "parent": 2,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_296": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 1,
#                 "svalue": 2.9000001
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.0144770211
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.0107313618
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_297": {
#             "Node_00": {
#                 "leaf_value": [
#                     0
#                 ],
#                 "left": null,
#                 "parent": null,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_298": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 1,
#                 "svalue": 2.79999995
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     0.0121253915
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     -0.00579718966
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         },
#         "Tree_299": {
#             "Node_00": {
#                 "leaf_value": [],
#                 "left": 1,
#                 "parent": null,
#                 "right": 2,
#                 "sindex": 2,
#                 "svalue": 5.0
#             },
#             "Node_01": {
#                 "leaf_value": [
#                     -0.0102347787
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             },
#             "Node_02": {
#                 "leaf_value": [
#                     0.013704475
#                 ],
#                 "left": null,
#                 "parent": 0,
#                 "right": null,
#                 "sindex": 0,
#                 "svalue": 0
#             }
#         }
#     },
#     "classes": [
#         0,
#         1,
#         2
#     ],
#     "metadata": {
#         "model": "xgboost.sklearn.XGBClassifier",
#         "version": "1.4.1.post1"
#     },
#     "options": {
#         "alpha": "0",
#         "base_score": "5E-1",
#         "boost_from_average": "1",
#         "booster": "gbtree",
#         "cache_opt": "1",
#         "colsample_bylevel": "1",
#         "colsample_bynode": "1",
#         "colsample_bytree": "1",
#         "device": "cpu",
#         "disable_default_eval_metric": "0",
#         "eta": "0.300000012",
#         "fail_on_invalid_gpu_id": "0",
#         "gamma": "0",
#         "grow_policy": "depthwise",
#         "hist_train_param": "name",
#         "interaction_constraints": "",
#         "lambda": "1",
#         "learning_rate": "0.300000012",
#         "max_bin": "256",
#         "max_cat_threshold": "64",
#         "max_cat_to_onehot": "4",
#         "max_delta_step": "0",
#         "max_depth": "6",
#         "max_leaves": "0",
#         "min_child_weight": "1",
#         "min_split_loss": "0",
#         "monotone_constraints": "()",
#         "multi_strategy": "one_output_per_tree",
#         "n_jobs": "0",
#         "name": "multi:softprob",
#         "nthread": "0",
#         "num_class": "3",
#         "num_feature": "4",
#         "num_parallel_tree": "1",
#         "num_target": "1",
#         "num_trees": "300",
#         "objective": "multi:softprob",
#         "process_type": "default",
#         "random_state": "0",
#         "refresh_leaf": "1",
#         "reg_alpha": "0",
#         "reg_lambda": "1",
#         "sampling_method": "uniform",
#         "seed": "0",
#         "seed_per_iteration": "0",
#         "sketch_ratio": "2",
#         "softmax_multiclass_param": {
#             "num_class": "3"
#         },
#         "sparse_threshold": "0.20000000000000001",
#         "subsample": "1",
#         "tree_method": "auto",
#         "updater": "grow_quantile_histmaker",
#         "updater_seq": "grow_quantile_histmaker",
#         "validate_parameters": "1"
#     }
# }
